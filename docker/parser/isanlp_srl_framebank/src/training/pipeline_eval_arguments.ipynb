# %%
import sys
sys.path.append("../")

# %%
import json
from pprint import pprint as print_
from collections import OrderedDict
import numpy as np
from numpy.random import RandomState
from tqdm import tqdm_notebook as tqdm

from isanlp_srl_framebank.pipeline_default import PipelineDefault

# %%
random_seed = 41

# %%
roleset44 = {
 'содержание высказывания',
 'говорящий',
 'субъект социального отношения',
 'субъект психологического состояния',
 'содержание действия',
 'агенс',
 'тема',
 'конечная точка',
 'сфера',
 'контрагент',
 'субъект перемещения',
 'причина',
 'субъект поведения',
 'ситуация в фокусе',
 'исходный посессор',
 'субъект физиологической реакции',
 'адресат',
 'пациенс',
 'срок',
 'источник звука',
 'место',
 'признак',
 'потенциальная угроза',
 'субъект ментального состояния',
 'конечный посессор',
 'результат',
 'стимул',
 'субъект восприятия',
 'эффектор',
 'траектория',
 'содержание мысли',
 'пациенс перемещения',
 'каузатор',
 'предмет высказывания',
 'начальная точка',
 'способ',
 'пациенс социального отношения',
 'статус',
 'предмет мысли',
 'цель',
 'потенциальный пациенс',
 'контрагент социального отношения',
 'эталон',
 'признак действия'}

# %%
ARGUMENT_POSTAGS = {
        'NOUN',
        'PRON',
        'ADJ',
        'PROPN'
    }

# %%
def get_roles_pred(lemma, role_annot, part_id):
    ann_sent = role_annot[part_id]
    predicates = {}
    arguments = {}
    for event in ann_sent:
        predicate = {
            'lemma': lemma[part_id][event.pred[0]],
        }
        predicates[event.pred[0]] = predicate
        arguments[event.pred[0]] = []
        for arg in event.args:
            argument = {
                'tag': arg.tag,
                'lemma': lemma[part_id][arg.begin],
                'idx': arg.begin
            }
            arguments[event.pred[0]].append(argument)
            
    return predicates, arguments


def get_example(corpus, ex_number, part_id):
    words = []
    for obj in corpus[ex_number][1][part_id]:
        word = obj['form']
        for symbol in ':;,.!?':
            word = word.replace(' ' + symbol, symbol)
        words.append(word)
        
    return ' '.join(words)


def get_roles_true(annot, corpus, ex_number, part_id):
    predicates = {}
    arguments = {}
    postags = [item for sublist in annot['postag'] for item in sublist]
    for i, obj in enumerate(corpus[ex_number][1][part_id]):
        if 'rank' in obj:
            if obj['rank'] == 'Предикат':
                predicate = {
                    'lemma': obj['lemma']
                }
                predicates[i] = predicate
            else:
                if 'lemma' not in obj:
                    argument = {
                        'lemma': obj['form'],
                        'tag': obj['rolepred1'],
                        'idx': i
                    }
                else:
                    argument = {
                        'lemma': obj['lemma'],
                        'tag': obj['rolepred1'],
                        'idx': i
                    }
                
                argument['postag'] = postags[argument['idx']]
                pred_id = obj['fillpred']
                if pred_id not in arguments.keys():
                    arguments[pred_id] = []
                arguments[pred_id].append(argument)
                
    return predicates, arguments

# %%
def random_predictions(corpus, ppl, n_samples=100):
    np.random.seed(random_seed)
    samples_idxs = np.random.choice(len(corpus), size=n_samples)
    
    texts = [get_example(corpus, ex_num, 0) for ex_num in samples_idxs]
    annotations = [ppl(text) for text in tqdm(texts, desc='Analyzing texts')]
    pred_roles = [get_roles_pred(res['lemma'], res['srl'], 0) for res in annotations]
    
    true_roles = [get_roles_true(annotations[i], corpus, ex_num, 0) for i, ex_num in enumerate(samples_idxs)]
    
    
    repl_roles = {
        'агенс - субъект восприятия' : 'субъект восприятия',
        'агенс - субъект ментального состояния' : 'субъект ментального состояния',
        'результат / цель' : 'результат',
        'место - пациенс' : 'место',
        'говорящий - субъект психологического состояния' : 'субъект психологического состояния'
    }
    
    for role, val in repl_roles.items():
        for pair in true_roles:
            for _, args in pair[1].items():
                for arg in args:
                    arg['tag'] = arg['tag'].replace(role, val)
                    
    return true_roles, pred_roles, texts


def compute_metrics(y_pred, y_true, report_to=sys.stdout, roleset=roleset44, idxmatching=False):
    true_positive = 0
    condition_positive = 0
    predicted_condition_positive = 0
    error_examples = []
    
    print_func = lambda x: print(x, file=report_to)
    
    for i, (true_predicates, true_arguments) in enumerate(y_true):
        print_func(f"Inspecting example {i}")
        print_func(f"Expecting true predicates {true_predicates}")
        print_func(f"Expecting true arguments  {true_arguments}")
        
        pred_predicates, pred_arguments = y_pred[i]

        print_func(f"Got predicted predicates  {pred_predicates}")
        print_func(f"Got predicted arguments   {pred_arguments}")
        
        print_func("-"*60)
        
        for true_pred_idx, true_predicate in true_predicates.items():
            if true_pred_idx in pred_predicates:
                print_func(f"Matched predicate {true_pred_idx} = {true_predicate}")
                
                true = true_arguments[true_pred_idx]
                pred_arguments_i = pred_arguments[true_pred_idx]
                
                true_arguments_i = []
                
                for idx, true_argument in enumerate(true):
                    if true_argument['tag'] in roleset and true_argument['postag'] in ARGUMENT_POSTAGS:
                        true_arguments_i.append(true[idx])
                        
                if true_arguments_i:
                    print_func(f"Expecting arguments  {true_arguments_i}")
                    print_func(f"Got predicted        {pred_arguments_i}")
                    print_func(f"Predicted Condition Positive = {len(pred_arguments_i)}")
                    print_func(f"Condition Positive           = {len(true_arguments_i)}")
                    condition_positive += len(true_arguments_i)
                    condition_positive_i = len(true_arguments_i)
                    predicted_condition_positive += len(pred_arguments_i)

                    true_positive_i = 0

                    error_report = {
                        'example_idx' : i,
                        'predicate': true_predicate,
                        'true_arguments' : true_arguments_i,
                        'predicted_arguments': pred_arguments_i
                    }

                    for j, obj in enumerate(true_arguments_i):
                        true_tag = obj['tag']
                        true_lemma = obj['lemma']
                        true_idx = obj['idx']
                        for obj_pred in pred_arguments_i:
                            if idxmatching:
                                if obj_pred['idx'] == true_idx:
                                    true_positive_i += 1
                            else:
                                if obj_pred['idx'] == true_idx and obj_pred['tag'] == true_tag:
                                    true_positive_i += 1

                    print_func(f"True Positive = {true_positive_i}")
                    if true_positive_i != condition_positive_i:
                        error_examples.append(error_report)

                    true_positive += true_positive_i
                
        print_func("="*60)
       
    recall = true_positive/condition_positive
    precision = true_positive/predicted_condition_positive
    
    return {
        'recall': recall,
        'precision': precision,
        'f1': 2 * ((precision*recall)/(precision+recall)),
        'errors': error_examples
    }

# %%
#corpus_name = 'annotated_corpus_fixed+syntaxnet.json'
corpus_path = '../../data/cleared_corpus.json'
with open(corpus_path, 'r', encoding='utf-8') as f:
    corpus = json.load(f)

# %%
import isanlp

# %%
! pip install -U git+https://github.com/tchewik/isanlp_srl_framebank.git
# Out:
# Collecting git+https://github.com/tchewik/isanlp_srl_framebank.git
#   Cloning https://github.com/tchewik/isanlp_srl_framebank.git to /tmp/pip-req-build-bv2jg62j
#   Running command git clone -q https://github.com/tchewik/isanlp_srl_framebank.git /tmp/pip-req-build-bv2jg62j
#   Running command git submodule update --init --recursive -q
# Building wheels for collected packages: isanl-srl-framebank
#   Building wheel for isanl-srl-framebank (setup.py) ... done
#   Created wheel for isanl-srl-framebank: filename=isanl_srl_framebank-0.0.1-cp36-none-any.whl size=13223 sha256=0d1570c165fc47d91ec1664d4b89a39d09a317ee9c0b72bb87daba96cbde86f9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8u019tq0/wheels/53/85/ca/d8697e680129d7344263e11de6f9c43c55721e83038ff90d95
# Successfully built isanl-srl-framebank
# Installing collected packages: isanl-srl-framebank
# Successfully installed isanl-srl-framebank-0.0.1

# %% [markdown]
# ### Metrics of argument extraction quality

# %%
host = 'vmh2.isa.ru'
host2 = 'echistova.isa.ru'
host3 = 'tsa05.isa.ru'

ppl = PipelineDefault(address_morph=(host, 4333),
                       address_syntax=(host, 4334),
                       address_srl=(host3, 4335))

# %%
ppl('Мама мыла раму.')
# Out:
# {'text': 'Мама мыла раму.',
#  'tokens': [<isanlp.annotation.Token at 0x7f2148c55c50>,
#   <isanlp.annotation.Token at 0x7f2148c55d30>,
#   <isanlp.annotation.Token at 0x7f2148c55f98>,
#   <isanlp.annotation.Token at 0x7f2148c55a90>],
#  'sentences': [<isanlp.annotation.Sentence at 0x7f2148c55c18>],
#  'mystem_postag': [['S,жен,од=им,ед',
#    'V,несов,пе=прош,ед,изъяв,жен',
#    'S,жен,неод=вин,ед',
#    '']],
#  'lemma': [['мама', 'мыть', 'рама', '.']],
#  'syntax_dep_tree': [[<isanlp.annotation.WordSynt at 0x7f21490b5208>,
#    <isanlp.annotation.WordSynt at 0x7f21490b5240>,
#    <isanlp.annotation.WordSynt at 0x7f21490b5080>,
#    <isanlp.annotation.WordSynt at 0x7f21490b5048>]],
#  'morph': [[{'fPOS': 'NOUN',
#     'Gender': 'Fem',
#     'Animacy': 'Anim',
#     'Case': 'Nom',
#     'Number': 'Sing'},
#    {'fPOS': 'VERB',
#     'Aspect': 'Imp',
#     'Valency': 'TR',
#     'Tense': 'Past',
#     'Number': 'Sing',
#     'VerbForm': 'Fin',
#     'Gender': 'Fem'},
#    {'fPOS': 'NOUN',
#     'Gender': 'Fem',
#     'Animacy': 'Inan',
#     'Case': 'Acc',
#     'Number': 'Sing'},
#    {}]],
#  'postag': [['NOUN', 'VERB', 'NOUN', '']],
#  'srl': [[<isanlp.annotation.Event at 0x7f2148c5b630>]]}

# %%
res = ppl('- И за это тебя посадят, -- как бы сообразив, прервала его тётя Катя.')

for event in res['srl'][0]:
    for i in range(len(event.args)):
        print(event.args[i].begin, f"({res['lemma'][0][event.args[i].begin]})", event.args[i].tag)
# Out:
# 3 (это) цель
# 4 (ты) пациенс
# 13 (он) пациенс
# 15 (катя) говорящий

# %%
res = ppl('- И за это тебя посадят, -- как бы сообразив, прервала его тётя Катя.')

for event in res['srl'][0]:
    for i in range(len(event.args)):
        print(event.args[i].begin, f"({res['lemma'][0][event.args[i].begin]})", event.args[i].tag)
# Out:
# 3 (это) цель
# 4 (ты) пациенс
# 13 (он) пациенс
# 15 (катя) говорящий

# %%
! pip install git+https://github.com/IINemo/isanlp.git@dev
# Out:
# Collecting git+https://github.com/IINemo/isanlp.git@dev
#   Cloning https://github.com/IINemo/isanlp.git (to revision dev) to /tmp/pip-req-build-vdscjvef
#   Running command git clone -q https://github.com/IINemo/isanlp.git /tmp/pip-req-build-vdscjvef
#   Running command git checkout -b dev --track origin/dev
#   Switched to a new branch 'dev'
#   Branch dev set up to track remote branch dev from origin.
# Requirement already satisfied (use --upgrade to upgrade): isanlp==0.0.6 from git+https://github.com/IINemo/isanlp.git@dev in /root/.pyenv/versions/3.6.7/lib/python3.6/site-packages
# Building wheels for collected packages: isanlp
#   Building wheel for isanlp (setup.py) ... done
#   Created wheel for isanlp: filename=isanlp-0.0.6-cp36-none-any.whl size=33540 sha256=385dc111a08506b97664aa578f99a6e77d8512014502908d4cb87b15bb22a45f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c60l3jrn/wheels/c2/22/fa/c2380ddd40a8fe7980f3ead4d7cbad4889975055f3bea6c15a
# Successfully built isanlp

# %% [markdown]
# n_samples=400 (usually)

# %%
true_roles, pred_roles, texts = random_predictions(corpus, ppl, n_samples=400)
# Out:
# HBox(children=(IntProgress(value=0, description='Analyzing texts', max=400), HTML(value='')))

# %%
log_path = 'log_idx.txt'
results = compute_metrics(y_pred=pred_roles, y_true=true_roles, 
                          report_to=open(log_path, 'w', encoding='utf-8'), 
                          idxmatching=True)

copyres = dict(results)
del copyres['errors']
print_(copyres)
# Out:
# {'f1': 0.7944444444444444,
#  'precision': 0.7447916666666666,
#  'recall': 0.8511904761904762}

# %%
log_path = 'log_idx.txt'
results = compute_metrics(y_pred=pred_roles, y_true=true_roles, 
                          report_to=open(log_path, 'w', encoding='utf-8'), 
                          idxmatching=False)

copyres = dict(results)
del copyres['errors']
print_(copyres)
# Out:
# {'f1': 0.6000000000000001, 'precision': 0.5625, 'recall': 0.6428571428571429}

# %% [markdown]
# #### Errors

# %%
import pandas as pd

ff = pd.DataFrame(results['errors'])

# %%
def neatify(text):
    return text.replace(' ,', ',')\
                .replace(' .', '.')\
                .replace(' ) ', ') ')\
                .replace(' ( ', ' (')\
                .replace(' : ', ': ')
                
ff['text'] = ff.example_idx.map(lambda idx: neatify(texts[idx]))

# %%
pd.set_option('display.max_colwidth', -1)

# %%
ff
# Out:
#     example_idx                       predicate  \
# 0   1            {'lemma': 'гладить'}
# 1   9            {'lemma': 'признать'}
# 2   24           {'lemma': 'выступить'}
# 3   25           {'lemma': 'глядеть'}
# 4   29           {'lemma': 'оценить'}
# 5   41           {'lemma': 'подобрать'}
# 6   44           {'lemma': 'гудеть'}
# 7   46           {'lemma': 'принудить'}
# 8   49           {'lemma': 'жить'}
# 9   52           {'lemma': 'прервать'}
# 10  72           {'lemma': 'бросаться'}
# 11  81           {'lemma': 'описать'}
# 12  102          {'lemma': 'предпочитать'}
# 13  116          {'lemma': 'кружить'}
# 14  140          {'lemma': 'заниматься'}
# 15  142          {'lemma': 'подвести'}
# 16  145          {'lemma': 'заявлять'}
# 17  149          {'lemma': 'подобрать'}
# 18  153          {'lemma': 'посетить'}
# 19  165          {'lemma': 'образоваться'}
# 20  168          {'lemma': 'формировать'}
# 21  170          {'lemma': 'владеть'}
# 22  171          {'lemma': 'ухаживать'}
# 23  172          {'lemma': 'оставаться'}
# 24  179          {'lemma': 'подойти'}
# 25  180          {'lemma': 'жить'}
# 26  194          {'lemma': 'пройти'}
# 27  197          {'lemma': 'варить'}
# 28  218          {'lemma': 'прошептать'}
# 29  224          {'lemma': 'угрожать'}
# 30  227          {'lemma': 'прыгать'}
# 31  233          {'lemma': 'возиться'}
# 32  239          {'lemma': 'отразить'}
# 33  257          {'lemma': 'достигать'}
# 34  267          {'lemma': 'схватиться'}
# 35  275          {'lemma': 'проконтролировать'}
# 36  276          {'lemma': 'приветствовать'}
# 37  316          {'lemma': 'найтись'}
# 38  323          {'lemma': 'взлететь'}
# 39  327          {'lemma': 'смотреть'}
# 40  335          {'lemma': 'прокричать'}
# 41  344          {'lemma': 'цитировать'}
# 42  358          {'lemma': 'укрепить'}
# 43  359          {'lemma': 'признать'}
# 44  363          {'lemma': 'нападать'}
# 45  372          {'lemma': 'демонстрировать'}
# 46  374          {'lemma': 'вставать'}
# 47  378          {'lemma': 'угодить'}
#
#                                                                                                                                                                                                                                                                                                                       predicted_arguments  \
# 0   [{'tag': 'тема', 'lemma': 'ладонь', 'idx': 9}, {'tag': 'агенс', 'lemma': 'он', 'idx': 0}]
# 1   [{'tag': 'говорящий', 'lemma': 'я', 'idx': 5}, {'tag': 'пациенс', 'lemma': 'сидней', 'idx': 8}, {'tag': 'адресат', 'lemma': 'свой', 'idx': 9}]
# 2   [{'tag': 'пациенс', 'lemma': 'партия', 'idx': 24}]
# 3   [{'tag': 'субъект восприятия', 'lemma': 'друг', 'idx': 6}]
# 4   [{'tag': 'содержание мысли', 'lemma': 'уникальность', 'idx': 25}, {'tag': 'агенс', 'lemma': 'человек', 'idx': 4}]
# 5   [{'tag': 'агенс', 'lemma': 'маруся', 'idx': 0}, {'tag': 'тема', 'lemma': 'ожерелие', 'idx': 4}]
# 6   [{'tag': 'источник звука', 'lemma': 'мой', 'idx': 67}]
# 7   [{'tag': 'пациенс', 'lemma': 'свой', 'idx': 16}]
# 8   [{'tag': 'содержание действия', 'lemma': 'стандарт', 'idx': 8}, {'tag': 'срок', 'lemma': 'пора', 'idx': 11}, {'tag': 'тема', 'lemma': 'образ', 'idx': 4}]
# 9   [{'tag': 'пациенс', 'lemma': 'он', 'idx': 13}, {'tag': 'говорящий', 'lemma': 'катя', 'idx': 15}]
# 10  [{'tag': 'агенс', 'lemma': 'женщина', 'idx': 26}, {'tag': 'субъект перемещения', 'lemma': 'икс', 'idx': 29}]
# 11  [{'tag': 'место', 'lemma': 'который', 'idx': 16}, {'tag': 'пациенс', 'lemma': 'результат', 'idx': 18}]
# 12  [{'tag': 'содержание мысли', 'lemma': 'что', 'idx': 0}, {'tag': 'субъект психологического состояния', 'lemma': 'переезд', 'idx': 4}, {'tag': 'эталон', 'lemma': 'место', 'idx': 7}]
# 13  [{'tag': 'субъект перемещения', 'lemma': 'надежда', 'idx': 17}, {'tag': 'пациенс перемещения', 'lemma': 'голова', 'idx': 22}]
# 14  [{'tag': 'агенс', 'lemma': 'сторона', 'idx': 2}, {'tag': 'сфера', 'lemma': 'то', 'idx': 35}, {'tag': 'тема', 'lemma': 'я', 'idx': 5}, {'tag': 'содержание мысли', 'lemma': 'равный', 'idx': 7}, {'tag': 'субъект ментального состояния', 'lemma': 'никто', 'idx': 8}, {'tag': 'содержание действия', 'lemma': 'проблема', 'idx': 13}]
# 15  [{'tag': 'агенс', 'lemma': 'он', 'idx': 1}, {'tag': 'конечная точка', 'lemma': 'стол', 'idx': 12}]
# 16  [{'tag': 'предмет высказывания', 'lemma': 'встреча', 'idx': 2}, {'tag': 'содержание высказывания', 'lemma': 'готовый', 'idx': 19}, {'tag': 'говорящий', 'lemma': 'сибур', 'idx': 11}]
# 17  [{'tag': 'агенс', 'lemma': 'маруся', 'idx': 0}, {'tag': 'тема', 'lemma': 'ожерелие', 'idx': 4}]
# 18  [{'tag': 'пациенс', 'lemma': 'форум', 'idx': 36}, {'tag': 'агенс', 'lemma': 'тот', 'idx': 28}]
# 19  [{'tag': 'пациенс', 'lemma': 'банк', 'idx': 1}, {'tag': 'тема', 'lemma': 'реализация', 'idx': 5}]
# 20  [{'tag': 'пациенс', 'lemma': 'то', 'idx': 1}, {'tag': 'агенс', 'lemma': 'внедрение', 'idx': 3}, {'tag': 'результат', 'lemma': 'инфраструктура', 'idx': 14}]
# 21  [{'tag': 'содержание мысли', 'lemma': 'мысль', 'idx': 2}, {'tag': 'тема', 'lemma': 'киркегор', 'idx': 4}]
# 22  [{'tag': 'пациенс', 'lemma': 'который', 'idx': 4}, {'tag': 'агенс', 'lemma': 'я', 'idx': 5}]
# 23  [{'tag': 'срок', 'lemma': 'утро', 'idx': 0}, {'tag': 'субъект перемещения', 'lemma': 'николаевна', 'idx': 2}, {'tag': 'тема', 'lemma': 'один', 'idx': 5}]
# 24  [{'tag': 'агенс', 'lemma': 'они', 'idx': 1}, {'tag': 'пациенс', 'lemma': 'бок', 'idx': 4}, {'tag': 'конечная точка', 'lemma': 'волк', 'idx': 7}]
# 25  [{'tag': 'тема', 'lemma': 'она', 'idx': 27}]
# 26  [{'tag': 'агенс', 'lemma': 'я', 'idx': 1}]
# 27  [{'tag': 'агенс', 'lemma': 'мотор', 'idx': 26}]
# 28  [{'tag': 'говорящий', 'lemma': 'женечка', 'idx': 8}]
# 29  [{'tag': 'пациенс', 'lemma': 'мнение', 'idx': 1}, {'tag': 'потенциальная угроза', 'lemma': 'обеспечение', 'idx': 15}, {'tag': 'адресат', 'lemma': 'мы', 'idx': 9}, {'tag': 'эффектор', 'lemma': 'вирус', 'idx': 7}]
# 30  [{'tag': 'траектория', 'lemma': 'ветка', 'idx': 49}, {'tag': 'субъект перемещения', 'lemma': 'баобаб', 'idx': 47}]
# 31  [{'tag': 'пациенс перемещения', 'lemma': 'неясность', 'idx': 16}]
# 32  [{'tag': 'место', 'lemma': 'она', 'idx': 19}, {'tag': 'пациенс', 'lemma': 'условие', 'idx': 21}]
# 33  [{'tag': 'конечная точка', 'lemma': 'м', 'idx': 21}, {'tag': 'результат', 'lemma': 'длина', 'idx': 23}, {'tag': 'субъект перемещения', 'lemma': 'полулежачий', 'idx': 12}]
# 34  [{'tag': 'агенс', 'lemma': 'я', 'idx': 0}, {'tag': 'конечная точка', 'lemma': 'пуговица', 'idx': 3}]
# 35  [{'tag': 'ситуация в фокусе', 'lemma': 'ход', 'idx': 9}]
# 36  [{'tag': 'говорящий', 'lemma': 'все', 'idx': 0}, {'tag': 'способ', 'lemma': 'аплодисменты', 'idx': 3}]
# 37  [{'tag': 'агенс', 'lemma': 'люба', 'idx': 4}, {'tag': 'тема', 'lemma': 'кассирша', 'idx': 20}, {'tag': 'пациенс', 'lemma': 'мастер', 'idx': 14}]
# 38  [{'tag': 'начальная точка', 'lemma': 'костер', 'idx': 5}, {'tag': 'тема', 'lemma': 'пепел', 'idx': 7}]
# 39  [{'tag': 'субъект восприятия', 'lemma': 'я', 'idx': 8}]
# 40  [{'tag': 'говорящий', 'lemma': 'он', 'idx': 18}]
# 41  [{'tag': 'контрагент', 'lemma': 'строка', 'idx': 2}]
# 42  [{'tag': 'пациенс', 'lemma': 'работа', 'idx': 8}, {'tag': 'агенс', 'lemma': 'комитет', 'idx': 4}]
# 43  [{'tag': 'содержание высказывания', 'lemma': 'функция', 'idx': 12}, {'tag': 'признак', 'lemma': 'необходимый', 'idx': 22}]
# 44  [{'tag': 'пациенс', 'lemma': 'слабый', 'idx': 4}]
# 45  [{'tag': 'стимул', 'lemma': 'отличие', 'idx': 23}]
# 46  [{'tag': 'цель', 'lemma': 'путь', 'idx': 4}, {'tag': 'субъект перемещения', 'lemma': 'калмыков', 'idx': 9}]
# 47  [{'tag': 'причина', 'lemma': 'сочувствие', 'idx': 39}]
#
#                                                                                                                                                                                                                        true_arguments  \
# 0   [{'lemma': 'он', 'tag': 'агенс', 'idx': 0, 'postag': 'PRON'}, {'lemma': 'ее', 'tag': 'тема', 'idx': 8, 'postag': 'PRON'}]
# 1   [{'lemma': 'я', 'tag': 'говорящий', 'idx': 5, 'postag': 'PRON'}, {'lemma': 'Сидней', 'tag': 'предмет высказывания', 'idx': 8, 'postag': 'NOUN'}, {'lemma': 'свой', 'tag': 'содержание высказывания', 'idx': 9, 'postag': 'PRON'}]
# 2   [{'lemma': 'партия', 'tag': 'говорящий', 'idx': 24, 'postag': 'NOUN'}, {'lemma': 'послание', 'tag': 'содержание высказывания', 'idx': 27, 'postag': 'NOUN'}]
# 3   [{'lemma': 'мы', 'tag': 'субъект восприятия', 'idx': 0, 'postag': 'PRON'}]
# 4   [{'lemma': 'человек', 'tag': 'субъект психологического состояния', 'idx': 4, 'postag': 'NOUN'}, {'lemma': 'уникальность', 'tag': 'причина', 'idx': 25, 'postag': 'NOUN'}]
# 5   [{'lemma': 'Маруся', 'tag': 'конечный посессор', 'idx': 0, 'postag': 'NOUN'}, {'lemma': 'ожерелье', 'tag': 'пациенс', 'idx': 4, 'postag': 'NOUN'}]
# 6   [{'lemma': 'кровь', 'tag': 'источник звука', 'idx': 66, 'postag': 'NOUN'}]
# 7   [{'lemma': 'генерал', 'tag': 'пациенс', 'idx': 0, 'postag': 'NOUN'}]
# 8   [{'lemma': 'образ', 'tag': 'тема', 'idx': 4, 'postag': 'NOUN'}, {'lemma': 'стандарт', 'tag': 'сфера', 'idx': 8, 'postag': 'NOUN'}, {'lemma': 'образ', 'tag': 'содержание мысли', 'idx': 13, 'postag': 'NOUN'}]
# 9   [{'lemma': 'он', 'tag': 'контрагент', 'idx': 13, 'postag': 'PRON'}, {'lemma': 'Катя', 'tag': 'говорящий', 'idx': 15, 'postag': 'NOUN'}]
# 10  [{'lemma': 'женщина', 'tag': 'конечная точка', 'idx': 26, 'postag': 'NOUN'}, {'lemma': 'икс', 'tag': 'субъект перемещения', 'idx': 29, 'postag': 'NOUN'}]
# 11  [{'lemma': 'Макуин', 'tag': 'говорящий', 'idx': 8, 'postag': 'NOUN'}, {'lemma': 'который', 'tag': 'место', 'idx': 16, 'postag': 'PRON'}, {'lemma': 'результат', 'tag': 'предмет высказывания', 'idx': 18, 'postag': 'NOUN'}]
# 12  [{'lemma': 'что', 'tag': 'содержание мысли', 'idx': 0, 'postag': 'PRON'}, {'lemma': 'выпускник', 'tag': 'субъект психологического состояния', 'idx': 2, 'postag': 'NOUN'}]
# 13  [{'lemma': 'надежда', 'tag': 'агенс', 'idx': 17, 'postag': 'NOUN'}, {'lemma': 'голова', 'tag': 'пациенс перемещения', 'idx': 22, 'postag': 'NOUN'}]
# 14  [{'lemma': 'никто', 'tag': 'агенс', 'idx': 8, 'postag': 'PRON'}, {'lemma': 'проблема', 'tag': 'содержание действия', 'idx': 13, 'postag': 'NOUN'}]
# 15  [{'lemma': 'он', 'tag': 'агенс', 'idx': 1, 'postag': 'PRON'}, {'lemma': 'он', 'tag': 'пациенс перемещения', 'idx': 6, 'postag': 'PRON'}, {'lemma': 'стол', 'tag': 'конечная точка', 'idx': 12, 'postag': 'NOUN'}]
# 16  [{'lemma': 'встреча', 'tag': 'сфера', 'idx': 2, 'postag': 'NOUN'}, {'lemma': 'президент', 'tag': 'говорящий', 'idx': 9, 'postag': 'NOUN'}, {'lemma': 'готовый', 'tag': 'содержание высказывания', 'idx': 19, 'postag': 'ADJ'}]
# 17  [{'lemma': 'Маруся', 'tag': 'конечный посессор', 'idx': 0, 'postag': 'NOUN'}, {'lemma': 'ожерелье', 'tag': 'пациенс', 'idx': 4, 'postag': 'NOUN'}]
# 18  [{'lemma': 'тот', 'tag': 'агенс', 'idx': 28, 'postag': 'PRON'}, {'lemma': 'форум', 'tag': 'сфера', 'idx': 36, 'postag': 'NOUN'}]
# 19  [{'lemma': 'банк', 'tag': 'тема', 'idx': 1, 'postag': 'NOUN'}]
# 20  [{'lemma': 'внедрение', 'tag': 'агенс', 'idx': 3, 'postag': 'NOUN'}, {'lemma': 'инфраструктура', 'tag': 'пациенс', 'idx': 14, 'postag': 'NOUN'}]
# 21  [{'lemma': 'мысль', 'tag': 'содержание мысли', 'idx': 2, 'postag': 'NOUN'}, {'lemma': 'Киркегор', 'tag': 'субъект психологического состояния', 'idx': 4, 'postag': 'NOUN'}]
# 22  [{'lemma': 'который', 'tag': 'контрагент социального отношения', 'idx': 4, 'postag': 'PRON'}, {'lemma': 'я', 'tag': 'субъект социального отношения', 'idx': 5, 'postag': 'PRON'}]
# 23  [{'lemma': 'Людмила', 'tag': 'тема', 'idx': 1, 'postag': 'NOUN'}]
# 24  [{'lemma': 'они', 'tag': 'субъект перемещения', 'idx': 1, 'postag': 'PRON'}, {'lemma': 'волк', 'tag': 'конечная точка', 'idx': 7, 'postag': 'NOUN'}]
# 25  [{'lemma': 'он', 'tag': 'тема', 'idx': 19, 'postag': 'PRON'}, {'lemma': 'она', 'tag': 'контрагент', 'idx': 27, 'postag': 'PRON'}]
# 26  [{'lemma': 'я', 'tag': 'субъект перемещения', 'idx': 1, 'postag': 'PRON'}]
# 27  [{'lemma': 'обшивка', 'tag': 'пациенс', 'idx': 29, 'postag': 'NOUN'}]
# 28  [{'lemma': 'ерунда', 'tag': 'содержание высказывания', 'idx': 4, 'postag': 'NOUN'}, {'lemma': 'женечка', 'tag': 'говорящий', 'idx': 8, 'postag': 'NOUN'}]
# 29  [{'lemma': 'мы', 'tag': 'потенциальный пациенс', 'idx': 9, 'postag': 'PRON'}, {'lemma': 'обеспечение', 'tag': 'потенциальная угроза', 'idx': 15, 'postag': 'NOUN'}]
# 30  [{'lemma': 'дикарка', 'tag': 'субъект перемещения', 'idx': 44, 'postag': 'NOUN'}, {'lemma': 'баобаб', 'tag': 'место', 'idx': 47, 'postag': 'NOUN'}, {'lemma': 'ветка', 'tag': 'траектория', 'idx': 49, 'postag': 'NOUN'}]
# 31  [{'lemma': 'историк', 'tag': 'агенс', 'idx': 11, 'postag': 'NOUN'}, {'lemma': 'неясность', 'tag': 'пациенс перемещения', 'idx': 16, 'postag': 'NOUN'}]
# 32  [{'lemma': 'она', 'tag': 'место', 'idx': 19, 'postag': 'PRON'}, {'lemma': 'условие', 'tag': 'тема', 'idx': 21, 'postag': 'NOUN'}]
# 33  [{'lemma': 'стебель', 'tag': 'тема', 'idx': 0, 'postag': 'NOUN'}]
# 34  [{'lemma': 'я', 'tag': 'агенс', 'idx': 0, 'postag': 'PRON'}, {'lemma': 'пуговица', 'tag': 'тема', 'idx': 3, 'postag': 'NOUN'}]
# 35  [{'lemma': 'кожин', 'tag': 'субъект ментального состояния', 'idx': 1, 'postag': 'NOUN'}, {'lemma': 'ход', 'tag': 'ситуация в фокусе', 'idx': 9, 'postag': 'NOUN'}]
# 36  [{'lemma': 'все', 'tag': 'говорящий', 'idx': 0, 'postag': 'PRON'}, {'lemma': 'их', 'tag': 'адресат', 'idx': 2, 'postag': 'PRON'}]
# 37  [{'lemma': 'другой', 'tag': 'тема', 'idx': 7, 'postag': 'PRON'}]
# 38  [{'lemma': 'костер', 'tag': 'начальная точка', 'idx': 5, 'postag': 'NOUN'}, {'lemma': 'пепел', 'tag': 'субъект перемещения', 'idx': 7, 'postag': 'NOUN'}]
# 39  [{'lemma': 'я', 'tag': 'предмет мысли', 'idx': 8, 'postag': 'PRON'}]
# 40  [{'lemma': 'дело', 'tag': 'содержание высказывания', 'idx': 5, 'postag': 'NOUN'}]
# 41  [{'lemma': 'строка', 'tag': 'контрагент', 'idx': 2, 'postag': 'NOUN'}, {'lemma': 'вавилов', 'tag': 'говорящий', 'idx': 6, 'postag': 'NOUN'}]
# 42  [{'lemma': 'вы', 'tag': 'агенс', 'idx': 6, 'postag': 'PRON'}, {'lemma': 'работа', 'tag': 'пациенс', 'idx': 8, 'postag': 'NOUN'}]
# 43  [{'lemma': 'функция', 'tag': 'предмет высказывания', 'idx': 12, 'postag': 'NOUN'}, {'lemma': 'необходимый', 'tag': 'содержание высказывания', 'idx': 22, 'postag': 'ADJ'}]
# 44  [{'lemma': 'хулиганье', 'tag': 'агенс', 'idx': 0, 'postag': 'NOUN'}, {'lemma': 'слабый', 'tag': 'пациенс', 'idx': 4, 'postag': 'ADJ'}]
# 45  [{'lemma': 'она', 'tag': 'агенс', 'idx': 15, 'postag': 'PRON'}, {'lemma': 'отличие', 'tag': 'стимул', 'idx': 23, 'postag': 'NOUN'}]
# 46  [{'lemma': 'путь', 'tag': 'место', 'idx': 4, 'postag': 'NOUN'}, {'lemma': 'калмыков', 'tag': 'субъект перемещения', 'idx': 9, 'postag': 'NOUN'}]
# 47  [{'lemma': 'сочувствие', 'tag': 'контрагент', 'idx': 39, 'postag': 'NOUN'}]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                             text
# 0   Он взял её за руку и стал гладить её ладонь, потом стал гладить её по плечу, коснулся шеи, затылка.
# 1   Человек городской, питерский, я сразу признал Сидней своим. Это город, что называется, с головы до пят ; на его улицах, в порту среди докеров, в кварталах Ву-ла-Мулла
# 2   С определёнными оговорками можно сказать, что развитие партийной системы в России во многом зависит от того, насколько успешно выступят " старые " партии с обновлённым посланием к избирателю.
# 3   Мы стояли молча, не глядя друг на друга, стояли и просто ждали, даже не подозревая, что ровно через два часа начнутся такие удивительные события, события, которые потрясут не только весь наш класс, но и всю школу...
# 4   в том, что люди часто пытаются повторить прошлый успех, выполняя работу абсолютно таким же образом, как и раньше, не пытаясь оценить уникальность новой ситуации. На самом деле, если кто-то раньше успешно выполнил определённую работу, вряд ли он повторит этот результат снова
# 5   Маруся подобрала шелестящее ракушечное ожерелье Эле-Фантика и побрела домой.
# 6   Я стал ловить девочкин взгляд, хотя никто в мире еще не поймал взгляда младенца, но я очень старался, я понимал, что эта безграничная ласка младенческого взгляда -- к миру вообще, жемчужно - серому безбрежному миру ; он не различает еще отдельностей, только смутные тени света, волны тепла, к тому же я не знал, где я сам, кровь моя гудела, было уже больно от этого... но если девочка уловит зрачки мои, то мы увидимся наконец !
# 7   Генерал встретил нас изъявлением искреннего своего сожаления о происшедшем и о том, что против хотения своего принуждён теперь лишиться нас.
# 8   Золотая Калифорния, этот образ живёт в американском стандарте до сих пор как образ земли обетованной, как основное, то есть западное направление.
# 9   -- И за это тебя посадят, -- как бы сообразив, прервала его тётя Катя.
# 10  Впрочем, методы менялись, и " гуманная " казнь по способу доктора Гильотена чередовалась с бесформенным пиршеством народа, когда к задушенной французской революционной толпой женщине бросался " икс ", распарывал ей грудь и впивался зубами в сердце.
# 11  В журнале " Труды АН США " Гленда Макуин из университета Макмастера опубликовала статью, в которой описала результаты обследования молодых людей, страдающих постпубертатной депрессией и попытками самоубийства. И показала, что чем больше депрессивных эпизодов, тем меньше объём
# 12  Что предпочитают выпускники -- переезд на постоянное место жительство или считают переезд временным ?
# 13  Маргарита слушала Коровьева, стараясь не проронить ни слова, под сердцем у неё было холодно, надежда на счастье кружила её голову.
# 14  С другой стороны, кроме меня всё равно никто не будет заниматься моими проблемами, поэтому если я не решила их сегодня, то завтра всё равно придётся и их решать, разница только в том, что решу я их на день позже, и у меня будет на одну бессонную ночь больше.
# 15  И он стал спешить -- снял его со стула, подвёл к столу, усадил и сам нагнулся над ним.
# 16  На последней встрече с журналистами и аналитиками вице - президент « СИБУРа » Сергей Зенкин заявил, что компания готова расплатиться по облигациям, если это потребуется.
# 17  Маруся подобрала шелестящее ракушечное ожерелье Эле-Фантика и побрела домой.
# 18  Кто стоит у истоков жизни человека, а порой возвращает её с того света, кто отвечает за здоровье, организует отдых людей и заботится о собственном, тот 1 - 3 февраля стремился посетить международный форум " Путешествие за здоровьем ", который был организован Центром мировых коммуникаций и состоялся в Российской академии государственной службы при Президенте РФ.
# 19  38 Банк образовался в ходе реализации первого этапа реформы немецкой почты в июле 1989 г., когда было принято решение выделить из единого государственного ведомства телекоммуникационную и банковскую службы, ставшие впоследствии совершенно самостоятельными организациями.
# 20  Кроме того, внедрение услуг WU и MG на национальных рынках не формирует финансовую инфраструктуру, а лишь использует уже имеющуюся (тем более, что агентами систем в большинстве случаев выступают нефинансовые организации ).
# 21  Та же мысль владела Киркегором, сближение которого с Ницше сделается едва ли не общим местом европейской критики конца XIX -- начала XX века.
# 22  -- Девушку, за которой я ухаживаю.
# 23  Утром Людмила Николаевна оставалась дома одна.
# 24  И они бок о бок подошли к Волку.
# 25  На втором году брака он понял вдруг (на Кузнецком мосту это произошло ), что не любя женился он на Але и не любя живёт с нею.
# 26  Немного я прошёл, как дрогнула сеть тумана -- обрушился на меня близкий выстрел, а за ним -- шум поднимающихся с воды крякух.
# 27  Всю осень и зиму, как приехали мы сюда с Валькой Марвичем, мы втроём ремонтировали этот катер, можно сказать, строили его заново: мотор перебрали, обшивку даже клепали и варили заново.
# 28  -- Господи, какая ерунда, -- прошептала Женечка.
# 29  По мнению Евгения Касперского, кроме собственного вируса, нам угрожает " дырявое " программное обеспечение, лень сисадминов и опасность (в лице некомпетентных пользователей) внутри самих компаний.
# 30  Нельзя идти к Мишиной ещё и потому, что та болезненно нетерпима к алкоголю, забеснуется, унюхав запашок, и Гастев поторопился домой, к бутылке коньяка, услаждая себя рассуждениями о человечестве, которое пресеклось бы ещё в каменном веке, вздумай дикарки прыгать на баобабе с ветки на ветку, отвергая нетерпеливых самцов.
# 31  Так ему и не дали рассказать, поэтому до сих пор историкам приходится возиться со всякими неясностями.
# 32  Мебель, являясь результатом творческой деятельности человека разных исторических эпох, представляет собой памятник материальной культуры общества, В ней отражены условия жизни, обычаи и вкусы людей, она характеризует уровень развития техники, даёт нам сведения о материалах и методах производства в определённый исторический период в данной стране.
# 33  Стебли аконитов обычно прямостоячие 50 -- 150 см высоты, иногда бывают полулежачие, полувьющиеся и вьющиеся и могут достигать 4 м в длину.
# 34  Я схватился за пуговицу, рванул... Где нож ?
# 35  Владимир Кожин приезжал в Петербург, чтобы лично проконтролировать ход работ по реконструкции Константиновского дворца в Стрельне.
# 36  Все приветствовали их аплодисментами.
# 37  -- Да, и Люба, и другие нашлись, солидарные с ней, мастера из мужского зала, и кассирша Алевтина Петровна.
# 38  Грошев махнул брюками -- с костра взлетел пепел, закружились его хлопья, словно моль, серые мотыльки.
# 39  -- Не знаю - с, а на меня так уж слишком смотрел, да и на Таню, приказчикову дочь, тоже ; да и на Пашу колбинскую, да грех сказать, никого не обидел, такой баловник !
# 40  -- Ну вот, секундное дело, а то людей пугать, -- перекрывая шум дизелей, прокричал он.
# 41  Цитируя пушкинские строки, С. Вавилов отмечает, что этот отрывок « гениален по своей глубине и значению для ученого », ибо « свидетельствует о проникновенном понимании Пушкиным методов научного творчества ».
# 42  -- Если бы Центральный Комитет поручил вам укрепить работу в Чека, разве вы можете отказаться ?
# 43  статус получило множество тех вспомогательных учреждений из состава министерств и управлений, функции которых в ходе сокращения громоздкого правительственного аппарата были признаны необходимыми, поскольку не могли быть переданы на исполнение частному сектору.
# 44  Хулиганье предпочитает нападать на слабых.
# 45  Однако успех « третьей колонны » был бы возможен лишь при условии, если бы она была последовательно оппозиционной и, демонстрируя свое отличие от КПРФ и националистов, не конфликтовала бы с компартией.
# 46  Пока не встал на пути председатель профкома участка Николай Калмыков, человек твердых принципов, ничем бригадиру не обязанный.
# 47  Мы ещё некоторое время проходим под холмом, на котором стоит дом моего двоюродного брата, и он ещё сверху следит за нами, и я, зная, что он сейчас жалеет меня, и чтоб угодить его сочувствию, стараюсь выглядеть ещё согбенней.
